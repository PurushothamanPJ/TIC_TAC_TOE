# %%
# THE BOARD:
row0 = [' ', ' ', ' ']
row1 = [' ', ' ', ' ']
row2 = [' ', ' ', ' ']
board = [row0, row1, row2]

from IPython.display import clear_output
clear_output()
from random import shuffle

# DISPLAYING THE BOARD:
def board_display():
    print(row0)
    print(row1)
    print(row2)

# WHO PLAYS FIRST:
def playing_order():    
    sample_space = ['h','t']
    shuffle(sample_space)
    guess = input('HEADS(h) OR TAILS(t) : ')
    if sample_space[0] == guess:
        print('YOU WON THE TOSS.YOU ARE PLAYER-1')
    if sample_space[0] != guess:
        print('YOU LOST THE TOSS.YOU ARE PLAYER-2')

########################################################################
# PLAYER - 1
########################################################################
# THE ROW IN WHICH THE USER WISHES TO PLACE HIS/HER "X" OR "Y":
def row_selection1():
    # clear_output()()
    Row_number1 = ''
    while Row_number1.isdigit() == False or int(Row_number1) not in range(3):
        Row_number1 = input('PLAYER-1 CHOOSE A ROW (0,1,2): ')
        if Row_number1.isdigit() == False:
            # clear_output()()
            print('ALPHABETS ARE NOT ACCEPTED.PLEASE GIVE AN INTEGER VALUE')
        elif int(Row_number1) not in range(3):
            # clear_output()()
            print('GIVEN NUMBER IS NOT IN (0,1,2)')
    # clear_output()()
    return int(Row_number1)

# THE INDEX POSITION IN WHICH THE USER WISHES TO PLACE HIS "X" OR "Y":
def selecting_index_position1():
    # clear_output()()
    Index_position1 = ''
    while Index_position1.isdigit() == False or int(Index_position1) not in range(3):
        Index_position1 = input('PLAYER-1 CHOOSE A COLUMN (0,1,2) : ')
        if Index_position1.isdigit() == False:
            # clear_output()()
            print('ALPHABETS ARE NOT ACCEPTED.PLEASE GIVE AN INTEGER VALUE')
        elif int(Index_position1) not in range(3):
            # clear_output()()
            print('GIVEN NUMBER IS NOT IN (0,1,2)')
    # clear_output()()
    return int(Index_position1)

# PREVENTING VARIABLE REPLACEMENT:
def preventing_variable_replacement1():
    global row_number1
    global index_position1
    while (row_number1,index_position1) not in total_spaces:
        board_display()
        print('HEY PLAYER-1 THIS POSITION IN THE BOARD IS ALREADY TAKEN.PLACE YOUR "X" SOMEWHERE ELSE')
        row_number1 = row_selection1()
        index_position1 = selecting_index_position1()
    
        if (row_number1,index_position1) not in total_spaces:
            clear_output()
            continue
        elif (row_number1,index_position1) in total_spaces:
            break
        
    occupied_spaces.append((row_number1,index_position1))
    total_spaces.remove((row_number1,index_position1))


# PRINTING X IN THE BOARD:
def display1(row_number1, index_position1):
    board[row_number1][index_position1] = "x"
    print(row0)
    print(row1)
    print(row2)
    

#############################################################################
# PLAYER - 2
#############################################################################
# THE ROW IN WHICH THE PLAYER -2 WISHES TO PLACE HIS/HER "O":
def row_selection2():
    # clear_output()()
    Row_number2 = ''
    while Row_number2.isdigit() == False or int(Row_number2) not in range(3):
        Row_number2 = input('PLAYER-2 CHOOSE A ROW (0,1,2): ')
        if Row_number2.isdigit() == False:
            # clear_output()()
            print('ALPHABETS ARE NOT ACCEPTED.PLEASE GIVE AN INTEGER VALUE')
        elif int(Row_number2) not in range(3):
            # clear_output()()
            print('GIVEN NUMBER IS NOT IN (0,1,2)')
    # clear_output()()
    return int(Row_number2)

# THE INDEX POSITION IN WHICH THE PLAYER - 2 WISHES TO PLACE HIS "O":
def selecting_index_position2():
    # clear_output()()
    Index_position2 = ''
    while Index_position2.isdigit() == False or int(Index_position2) not in range(3):
        Index_position2 = input('PLAYER-2 CHOOSE A COLUMN (0,1,2) : ')
        if Index_position2.isdigit() == False:
            # clear_output()()
            print('ALPHABETS ARE NOT ACCEPTED.PLEASE GIVE AN INTEGER VALUE')
        elif int(Index_position2) not in range(3):
            # clear_output()()
            print('GIVEN NUMBER IS NOT IN (0,1,2)')
    # clear_output()()
    return int(Index_position2)

# PREVENTING VARIABLE REPLACEMENT:
def preventing_variable_replacement2():
    global row_number2
    global index_position2
    while (row_number2,index_position2) not in total_spaces:
        board_display()
        print('HEY PLAYER-2 THIS POSITION IN THE BOARD IS ALREADY TAKEN.PLACE YOUR "O" SOMEWHERE ELSE')
        row_number2 = row_selection2()
        index_position2 = selecting_index_position2()
    
        if (row_number2,index_position2) not in total_spaces:
            clear_output()
            continue
        elif (row_number2,index_position2) in total_spaces:
            break
        
    occupied_spaces.append((row_number2,index_position2))
    total_spaces.remove((row_number2,index_position2))


# PRINTING "O" IN THE BOARD:
def display2(row_number2, index_position2):
    board[row_number2][index_position2] = 'o'
    print(row0)
    print(row1)
    print(row2)
    
#############################################################################
# THE WINNER DETERMINING FUNCTION:
#############################################################################

def three_x():
    # HORIZONTAL
    if board[0][0] =='x' and board[0][1] =='x' and board[0][2] =='x':
        return True  
    if board[1][0] =='x' and board[1][1] =='x' and board[1][2] =='x':
        return True   
    if board[2][0] =='x' and board[2][1] =='x' and board[2][2] =='x':
        return True 
    # VERTICAL
    if board[0][0] =='x' and board[1][0] =='x' and board[2][0] =='x':
        return True   
    if board[0][1] =='x' and board[1][1] =='x' and board[2][1] =='x':
        return True
    if board[0][2] =='x' and board[1][2] =='x' and board[2][2] =='x':
        return True
    # DIAGONAL
    if board[0][0] =='x' and board[1][1] =='x' and board[2][2] =='x':
        return True            
    if board[0][2] =='x' and board[1][1] =='x' and board[2][0] =='x':
        return True     
    
def three_o():
    # HORIZONTAL
    if board[0][0] =='o' and board[0][1] =='o' and board[0][2] =='o':
        return True                 
    if board[1][0] =='o' and board[1][1] =='o' and board[1][2] =='o':
        return True                 
    if board[2][0] =='o' and board[2][1] =='o' and board[2][2] =='o':
        return True                 
    # VERTICAL
    if board[0][0] =='o' and board[1][0] =='o' and board[2][0] =='o':
        return True                 
    if board[0][1] =='o' and board[1][1] =='o' and board[2][1] =='o':
        return True         
    if board[0][2] =='o' and board[1][2] =='o' and board[2][2] =='o':
        return True                 
    # DIAGONAL
    if board[0][0] =='o' and board[1][1] =='o' and board[2][2] =='o':
        return True                 
    if board[0][2] =='o' and board[1][1] =='o' and board[2][0] =='o':
        return True 
#############################################################################################    
# TURNS:
#############################################################################################
turns1 = [1,2,3,4,5]
turns2 = [1,2,3,4]

def pop_turns1():
    global turns1
    turns1.pop(0)

def pop_turns2():
    global turns2
    turns2.pop(0)

# %%
# GAME FLOW:

while True:
    # THE BOARD:
    row0 = [' ', ' ', ' ']
    row1 = [' ', ' ', ' ']
    row2 = [' ', ' ', ' ']
    board = [row0, row1, row2]
    
    # NO OF TURNS FOR PLAYER-1 AND PLAYER-2:
    turns1 = [1,2,3,4,5]
    turns2 = [1,2,3,4]

    # OCCUPIED AND UNOCCUPIED SPACES:
    total_spaces = [(0,0),(0,1),(0,2),(1,0),(1,1),(1,2),(2,0),(2,1),(2,2)]
    occupied_spaces = []
    
    # WHO'S FIRST:
    playing_order()
    
    while True:
            # DISPLAYS THE UPDATED BOARD
            board_display()
            
            row_number1 = row_selection1()
            index_position1 = selecting_index_position1()
            preventing_variable_replacement1()
            display1(row_number1,index_position1)
            three_x()
            # WINNER CHECK
            if three_x() == True:
                clear_output()
                board_display()
                print('PLAYER-1 HAS WON THE MATCH')
                break
            pop_turns1()
            # IT'S A TIE
            if len(turns1) == 0:
                clear_output()
                board_display()
                print('IT IS A TIE')
                break


            row_number2 = row_selection2()
            index_position2 = selecting_index_position2()
            preventing_variable_replacement2()
            display2(row_number2,index_position2)
            three_o()
            # WINNER CHECK
            if three_o() == True:
                clear_output()
                board_display()
                print('PLAYER-2 HAS WON THE MATCH')
                break
            pop_turns2()
            clear_output()
    
    # WANNA PLAY AGAIN:
    reply = input('DO YOU WANNA PLAY AGAIN yes/no : ')
    if reply == 'no':
        break
# Out:
# ['x', 'o', 'o']
# ['x', 'o', ' ']
# ['x', ' ', 'x']
# PLAYER-1 HAS WON THE MATCH
# DO YOU WANNA PLAY AGAIN yes/no : no
